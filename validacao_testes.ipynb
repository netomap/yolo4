# %%
from model import Model
from utils import carregar_modelo, predict
import torch
from torch import nn
import pathlib
from torchvision import transforms
from PIL import Image, ImageDraw
from create_dataset import create_image

# %%
model = carregar_modelo('./checkpoints/checkpoint_53.pth')
# Out:
# <All keys matched successfully>

# %%
img_pil, _ = create_image(6)
img_pil, anotacoes = predict(model, img_pil, prob_threshold=.99, class_threshold=0.50)
img_pil
# Out:
# <PIL.Image.Image image mode=RGB size=375x361 at 0x2A46DE3D340>
